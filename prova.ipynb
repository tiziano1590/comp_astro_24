# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # prova testo
# sottotitolo $\frac{M_{\odot}}{R_{\odot}}$

# %%
x = [1,2,3,4,5]
y = [3,1,4,2,5]

plt.plot(x,y,'ro')
plt.show()
